# %%
# 분류 모델 생성
# !yolo classify train data=./dataset model=./ultralytics/ultralytics/cfg/models/v8/yolov8-cls.yaml epochs=10
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# YOLOv8-cls summary: 99 layers, 2,719,288 parameters, 2,719,288 gradients, 4.4 GFLOPs
# Ultralytics YOLOv8.2.91 🚀 Python-3.11.5 torch-2.4.1 CPU (Apple M2)
# ...

# %%
# !yolo predict model=yolov8n.pt source=0
