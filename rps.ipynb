# %%
import cv2
import os
import glob
import time
from ultralytics import YOLO
import warnings
# !pwd
# Out:
# /Users/jeongmungyeong/Desktop/Project/VSCode/yolo8-RPS

# %%
# 객체 탐지 및 분류 모델 불러오기
try:
    detect_model = YOLO('./yolov8n.pt')  # 객체 탐지 모델
    classify_model = YOLO('./models/yolov8_clsRPS.pt')  # 분류 모델
except Exception as e:
    print(f"모델 로딩 중 오류 발생: {e}")
    exit()

# 객체 사진을 저장할 폴더 설정
save_dir = "class"  # 객체 사진을 저장할 폴더 이름
os.makedirs(save_dir, exist_ok=True)

# 분류된 객체의 이미지를 저장할 폴더 설정 (원하는 경로로 변경 가능)
classified_save_dir = "./class"
os.makedirs(classified_save_dir, exist_ok=True)

# 웹캠 설정 (0번 카메라 사용)
cap = cv2.VideoCapture(1)

# 웹캠이 열리지 않는 경우 종료
if not cap.isOpened():
    print("웹캠을 열 수 없습니다.")
    exit()
# Out:
# 2024-09-11 22:05:25.802 python[48593:4105024] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.

# %%
# 바운딩 박스를 확장하는 비율
EXPAND_RATIO = 0.0  # 20% 더 넓게 확장

# 폴더 내의 모든 파일 삭제 함수
def clear_folder(folder_path):
    try:
        files = glob.glob(f"{folder_path}/*")
        for f in files:
            os.remove(f)
    except Exception as e:
        print(f"폴더 정리 중 오류 발생: {e}")

# %%
# 분류 작업 수행 함수 (이미지 저장 포함)
def classify_image(image):
    try:
        # 이미지를 분류 모델에 직접 전달하여 예측 수행
        results = classify_model.predict(source=image)
        # 분류 결과 얻기
        if results and len(results) > 0:
            # 각 클래스의 확률을 가져와서 텍스트로 표시
            top1_probs = results[0].probs.data  # 모든 클래스 확률 가져오기
            class_names = results[0].names  # 클래스 이름들
            
            # 확률과 클래스 이름 매칭
            prob_text = ', '.join([f"{class_names[i]}: {prob:.2f}" for i, prob in enumerate(top1_probs)])
            
            # 분류된 결과를 저장 (예시)
            save_path = os.path.join(classified_save_dir, f"classification_{int(time.time() * 1000)}.jpg")
            cv2.imwrite(save_path, image)  # 분류된 이미지를 저장
            
            return prob_text
    except Exception as e:
        print(f"예기치 않은 분류 오류: {e}")
    return None

# %%
# 객체 탐지 및 분류 함수
def run_detection_and_classification():
    clear_folder(save_dir)
    
    # 명시적으로 창 생성
    cv2.namedWindow("Detection and Classification", cv2.WINDOW_NORMAL)
    while True:
        try:
            # 시작 시 class 폴더의 모든 파일 삭제
            # clear_folder(save_dir)

            ret, frame = cap.read()
            if not ret:
                print("카메라에서 프레임을 가져올 수 없습니다.")
                break  # 문제 발생 시 루프 종료

            # 객체 탐지 (저장 비활성화)
            try:
                detection_results = detect_model.predict(source=frame, save=False, save_crop=False, show=False)
            except Exception as e:
                print(f"객체 탐지 중 오류 발생: {e}")
                continue

            # 객체 탐지 시 분류 수행
            for result in detection_results:
                for box in result.boxes:
                    # 탐지된 객체의 클래스 이름 가져오기
                    class_id = int(box.cls[0])
                    class_name = result.names[class_id]
                    
                    # 'person' 클래스인 경우에만 분류 수행
                    if class_name == 'person':
                        # 바운딩 박스 확장
                        x1, y1, x2, y2 = map(int, box.xyxy[0])
                        width = x2 - x1
                        height = y2 - y1

                        # 확장된 좌표 계산
                        expand_x = int(width * EXPAND_RATIO)
                        expand_y = int(height * EXPAND_RATIO)

                        # 확장된 좌표가 이미지 범위를 넘어가지 않도록 조정
                        x1 = max(0, x1 - expand_x)
                        y1 = max(0, y1 - expand_y)
                        x2 = min(frame.shape[1], x2 + expand_x)
                        y2 = min(frame.shape[0], y2 + expand_y)

                        try:
                            # 확장된 영역을 잘라서 분류 모델에 전달
                            detected_object = frame[y1:y2, x1:x2]
                            
                            # 분류 작업 수행
                            predicted_class = classify_image(detected_object)
                            
                            # 분류 모델이 인식된 경우 결과 표시 및 저장
                            if predicted_class is not None:
                                # 이미지에 분류 결과 표시
                                cv2.putText(frame, predicted_class, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)
                                cv2.rectangle(frame, (x1, y1), (x2, y2), (36, 255, 12), 2)
                                
                                # 분류된 결과를 저장
                                # save_path = os.path.join(classified_save_dir, f"{predicted_class}_{int(time.time() * 1000)}.jpg")
                                # cv2.imwrite(save_path, detected_object)
                        except cv2.error as e:
                            print(f"OpenCV 에러: {e}")
                        except Exception as e:
                            print(f"예기치 않은 에러: {e}")
            
            # 결과 프레임을 화면에 표시
            try:
                cv2.imshow("Detection and Classification", frame)
                key = cv2.waitKey(1)
            except cv2.error as e:
                print(f"cv2.imshow() 에러: {e}")
            except Exception as e:
                print(f"cv2.waitKey() 에러: {e}")
            
        except Exception as e:
            print(f"루프 중 예외 발생: {e}")
            break  # 심각한 오류 발생 시 루프 중지

    # 모든 리소스 해제
    cap.release()
    cv2.destroyAllWindows()

# %%
# 단일 스레드로 함수 실행
run_detection_and_classification()
# Out:
# 0: 384x640 1 person, 55.9ms
# Speed: 2.3ms preprocess, 55.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.00, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.7ms
# Speed: 1.6ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, scissors 0.03, paper 0.01, 5.1ms
# Speed: 2.3ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 49.0ms
# Speed: 1.9ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, scissors 0.05, paper 0.02, 4.7ms
# Speed: 1.9ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, scissors 0.05, paper 0.02, 5.2ms
# Speed: 2.9ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, scissors 0.04, paper 0.01, 4.8ms
# Speed: 1.8ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.9ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, scissors 0.04, paper 0.01, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 48.2ms
# Speed: 1.8ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.8ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.09, paper 0.02, 5.2ms
# Speed: 2.0ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.9ms
# Speed: 1.6ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.84, scissors 0.13, paper 0.03, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 50.1ms
# Speed: 2.0ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.85, scissors 0.12, paper 0.03, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 4.5ms
# Speed: 2.3ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.86, paper 0.07, scissors 0.07, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.85, paper 0.15, scissors 0.00, 5.9ms
# Speed: 1.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.85, paper 0.15, scissors 0.00, 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.80, paper 0.20, scissors 0.00, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.72, paper 0.28, scissors 0.01, 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.06, paper 0.01, 15.5ms
# Speed: 33.9ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 1.8ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, paper 0.11, scissors 0.01, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.86, scissors 0.11, paper 0.03, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 51.2ms
# Speed: 1.9ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.77, paper 0.21, scissors 0.02, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.81, scissors 0.15, paper 0.04, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.72, paper 0.27, scissors 0.01, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.87, scissors 0.11, paper 0.02, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.86, paper 0.14, scissors 0.01, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.94, scissors 0.03, paper 0.02, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, paper 0.09, scissors 0.02, 5.7ms
# Speed: 2.0ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, paper 0.01, scissors 0.00, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.67, rock 0.28, paper 0.06, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.84, paper 0.15, scissors 0.01, 5.5ms
# Speed: 1.9ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, paper 0.01, scissors 0.01, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.05, scissors 0.01, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, paper 0.01, scissors 0.01, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.5ms
# Speed: 2.9ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, paper 0.06, scissors 0.01, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 16.8ms
# Speed: 45.5ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.5ms
# Speed: 1.9ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.06, scissors 0.00, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, paper 0.08, scissors 0.00, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, paper 0.08, scissors 0.00, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.7ms
# Speed: 2.0ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, paper 0.04, scissors 0.01, 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.9ms
# Speed: 1.6ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, paper 0.06, scissors 0.01, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.4ms
# Speed: 1.9ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, paper 0.09, scissors 0.02, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.4ms
# Speed: 2.2ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, paper 0.09, scissors 0.01, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 6.3ms
# Speed: 3.2ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.1ms
# Speed: 1.7ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.05, scissors 0.00, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, paper 0.09, scissors 0.01, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, paper 0.11, scissors 0.01, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 4.2ms
# Speed: 2.0ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.7ms
# Speed: 1.9ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.04, scissors 0.02, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 4.7ms
# Speed: 3.0ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, paper 0.03, scissors 0.01, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 6.0ms
# Speed: 1.9ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, paper 0.04, scissors 0.02, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, paper 0.10, scissors 0.01, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.03, scissors 0.03, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 53.3ms
# Speed: 1.6ms preprocess, 53.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, paper 0.03, scissors 0.01, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, paper 0.03, scissors 0.02, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.3ms
# Speed: 1.7ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, paper 0.03, scissors 0.03, 8.3ms
# Speed: 14.1ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.01, 6.5ms
# Speed: 3.7ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, paper 0.06, scissors 0.01, 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.3ms
# Speed: 5.2ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 49.3ms
# Speed: 1.8ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.02, 6.8ms
# Speed: 4.4ms preprocess, 6.8ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, paper 0.01, scissors 0.01, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.96, paper 0.04, scissors 0.00, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 52.3ms
# Speed: 1.9ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.01, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 1.00, paper 0.00, scissors 0.00, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 47.7ms
# Speed: 1.4ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.04, paper 0.04, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, paper 0.01, scissors 0.00, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 60.7ms
# Speed: 1.3ms preprocess, 60.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.04, scissors 0.01, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 vase, 61.8ms
# Speed: 1.9ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, paper 0.07, scissors 0.01, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, paper 0.06, scissors 0.01, 20.1ms
# Speed: 35.7ms preprocess, 20.1ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 sports ball, 60.1ms
# Speed: 1.6ms preprocess, 60.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, scissors 0.03, paper 0.02, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.46, paper 0.27, scissors 0.27, 10.8ms
# Speed: 7.2ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, paper 0.04, scissors 0.04, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.91, scissors 0.06, paper 0.04, 6.7ms
# Speed: 3.6ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, paper 0.06, scissors 0.01, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 62.1ms
# Speed: 1.7ms preprocess, 62.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.04, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, paper 0.01, scissors 0.01, 6.7ms
# Speed: 3.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.91, paper 0.05, scissors 0.04, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 8.0ms
# Speed: 3.7ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.87, scissors 0.09, paper 0.04, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.5ms
# Speed: 3.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, scissors 0.06, paper 0.02, 10.7ms
# Speed: 6.7ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 55.8ms
# Speed: 2.6ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.87, scissors 0.08, paper 0.04, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.94, scissors 0.04, paper 0.01, 6.2ms
# Speed: 5.9ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 scissors, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 33.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.06, paper 0.05, 6.6ms
# Speed: 12.0ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.06, paper 0.02, 8.9ms
# Speed: 5.3ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 1 scissors, 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.85, scissors 0.09, paper 0.06, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.91, scissors 0.07, paper 0.02, 6.7ms
# Speed: 4.6ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 52.6ms
# Speed: 1.6ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, scissors 0.04, paper 0.03, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.00, paper 0.00, 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.91, scissors 0.07, paper 0.02, 8.2ms
# Speed: 5.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 52.8ms
# Speed: 1.7ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.91, scissors 0.06, paper 0.03, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.51, scissors 0.43, paper 0.06, 7.1ms
# Speed: 3.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.86, scissors 0.11, paper 0.02, 9.1ms
# Speed: 5.4ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.9ms
# Speed: 1.7ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.63, rock 0.33, paper 0.04, 8.3ms
# Speed: 4.8ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 49.2ms
# Speed: 1.6ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.04, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.52, rock 0.44, paper 0.04, 4.8ms
# Speed: 4.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 5.4ms
# Speed: 3.8ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 44.9ms
# Speed: 4.5ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.04, paper 0.04, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.82, rock 0.13, paper 0.05, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 9.0ms
# Speed: 3.7ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 65.5ms
# Speed: 32.5ms preprocess, 65.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, scissors 0.04, paper 0.03, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.82, rock 0.14, paper 0.04, 7.1ms
# Speed: 5.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 46.2ms
# Speed: 1.8ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, scissors 0.04, paper 0.03, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 47.8ms
# Speed: 1.8ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, scissors 0.03, paper 0.03, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.00, paper 0.00, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 7.9ms
# Speed: 4.2ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 47.8ms
# Speed: 1.9ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.82, rock 0.14, paper 0.04, 6.9ms
# Speed: 4.9ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 59.1ms
# Speed: 1.8ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 6.8ms
# Speed: 3.1ms preprocess, 6.8ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.72, rock 0.24, paper 0.04, 7.0ms
# Speed: 5.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.59, scissors 0.37, paper 0.04, 5.4ms
# Speed: 5.8ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 3 persons, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.51, rock 0.45, paper 0.04, 5.7ms
# Speed: 5.1ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.2ms
# Speed: 2.7ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 scissors 0.69, rock 0.27, paper 0.04, 39.7ms
# Speed: 6.5ms preprocess, 39.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 toothbrush, 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.3ms
# Speed: 1.7ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 7.3ms
# Speed: 2.9ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.55, scissors 0.36, paper 0.09, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 vase, 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 53.9ms
# Speed: 1.3ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.93, scissors 0.05, paper 0.03, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 scissors, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.8ms
# Speed: 3.6ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 1.00, paper 0.00, scissors 0.00, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 8.1ms
# Speed: 3.2ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 1 scissors, 48.7ms
# Speed: 1.6ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 paper 0.63, scissors 0.37, rock 0.00, 6.2ms
# Speed: 3.4ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.87, scissors 0.10, paper 0.03, 7.6ms
# Speed: 2.9ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.91, scissors 0.06, paper 0.03, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.9ms
# Speed: 1.5ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 sports ball, 1 wine glass, 52.5ms
# Speed: 1.8ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 sports ball, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 49.7ms
# Speed: 1.3ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 wine glass, 2 vases, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 sports ball, 1 orange, 48.9ms
# Speed: 1.3ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 1 sports ball, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 frisbee, 1 sports ball, 1 orange, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 paper 0.97, rock 0.03, scissors 0.01, 6.8ms
# Speed: 4.7ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.91, scissors 0.06, paper 0.03, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 sports ball, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 paper 0.95, scissors 0.05, rock 0.00, 7.5ms
# Speed: 5.7ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 wine glass, 1 apple, 59.1ms
# Speed: 11.6ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 paper 0.69, scissors 0.31, rock 0.00, 7.2ms
# Speed: 3.7ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 1 wine glass, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.74, paper 0.25, rock 0.01, 8.1ms
# Speed: 5.4ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.04, paper 0.03, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.65, paper 0.32, rock 0.03, 8.5ms
# Speed: 3.7ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.05, paper 0.03, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.60, paper 0.37, rock 0.04, 6.9ms
# Speed: 5.3ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.04, paper 0.03, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.63, paper 0.35, rock 0.01, 7.2ms
# Speed: 4.8ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.05, paper 0.03, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.60, paper 0.39, rock 0.01, 7.9ms
# Speed: 5.1ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.53, paper 0.45, rock 0.02, 9.5ms
# Speed: 4.6ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 7.4ms
# Speed: 1.3ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 paper 0.48, scissors 0.48, rock 0.04, 7.0ms
# Speed: 5.2ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 90.1ms
# Speed: 1.6ms preprocess, 90.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.56, paper 0.43, rock 0.01, 5.6ms
# Speed: 4.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.03, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.60, paper 0.38, rock 0.01, 7.3ms
# Speed: 3.3ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.5ms
# Speed: 2.2ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.57, paper 0.40, rock 0.03, 5.8ms
# Speed: 4.6ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.87, scissors 0.10, paper 0.03, 4.6ms
# Speed: 2.4ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.58, paper 0.39, rock 0.02, 5.7ms
# Speed: 3.3ms preprocess, 5.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 5.7ms
# Speed: 2.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.2ms
# Speed: 2.3ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.55, paper 0.42, rock 0.04, 6.7ms
# Speed: 4.8ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.87, scissors 0.09, paper 0.03, 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.57, paper 0.39, rock 0.04, 6.6ms
# Speed: 3.4ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 56.4ms
# Speed: 1.8ms preprocess, 56.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.62, paper 0.34, rock 0.04, 8.4ms
# Speed: 3.8ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.62, paper 0.33, rock 0.05, 8.5ms
# Speed: 3.9ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.86, scissors 0.10, paper 0.03, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.4ms
# Speed: 1.7ms preprocess, 53.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.58, paper 0.38, rock 0.04, 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.87, scissors 0.10, paper 0.03, 48.7ms
# Speed: 2.3ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.58, paper 0.37, rock 0.05, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 57.8ms
# Speed: 2.5ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.54, paper 0.41, rock 0.05, 8.5ms
# Speed: 3.6ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.89, scissors 0.08, paper 0.03, 10.1ms
# Speed: 1.6ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 48.5ms
# Speed: 3.2ms preprocess, 48.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.60, paper 0.34, rock 0.06, 5.1ms
# Speed: 3.8ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.91, scissors 0.06, paper 0.03, 4.4ms
# Speed: 2.0ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.61, paper 0.32, rock 0.07, 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, scissors 0.05, paper 0.03, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.63, paper 0.33, rock 0.05, 7.9ms
# Speed: 4.3ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 53.8ms
# Speed: 2.1ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.62, paper 0.34, rock 0.04, 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.07, paper 0.03, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 47.8ms
# Speed: 1.9ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.59, paper 0.36, rock 0.05, 6.4ms
# Speed: 5.2ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.04, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.64, paper 0.31, rock 0.05, 6.4ms
# Speed: 3.9ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.04, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.8ms
# Speed: 10.0ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 scissors 0.64, paper 0.30, rock 0.06, 6.8ms
# Speed: 3.8ms preprocess, 6.8ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.04, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 50.4ms
# ...
#
# 0: 224x224 rock 0.85, scissors 0.11, paper 0.04, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, paper 0.03, scissors 0.01, 8.1ms
# Speed: 3.9ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.84, scissors 0.11, paper 0.05, 6.1ms
# Speed: 16.3ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 49.6ms
# Speed: 2.1ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.01, 6.4ms
# Speed: 4.3ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.87, scissors 0.10, paper 0.04, 5.5ms
# Speed: 3.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, scissors 0.02, paper 0.02, 8.3ms
# Speed: 4.4ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, scissors 0.06, paper 0.04, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 94.4ms
# Speed: 1.9ms preprocess, 94.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.01, 10.2ms
# Speed: 4.9ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.89, scissors 0.07, paper 0.04, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 52.7ms
# Speed: 1.8ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.02, 6.6ms
# Speed: 4.0ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, paper 0.05, scissors 0.04, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.01, 8.2ms
# Speed: 4.0ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.90, paper 0.05, scissors 0.05, 11.3ms
# Speed: 2.7ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.9ms
# Speed: 2.2ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, paper 0.02, scissors 0.01, 9.6ms
# Speed: 3.9ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, paper 0.06, scissors 0.02, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 60.3ms
# Speed: 2.9ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.01, scissors 0.01, 6.4ms
# Speed: 3.8ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, paper 0.05, scissors 0.03, 9.4ms
# Speed: 18.3ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 58.4ms
# Speed: 1.7ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.02, scissors 0.02, 9.0ms
# Speed: 4.9ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.92, paper 0.05, scissors 0.03, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 110.5ms
# Speed: 4.5ms preprocess, 110.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, paper 0.01, scissors 0.01, 4.8ms
# Speed: 4.6ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.93, scissors 0.04, paper 0.03, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 54.1ms
# Speed: 1.9ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, paper 0.01, scissors 0.00, 6.6ms
# Speed: 4.9ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.94, paper 0.04, scissors 0.01, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 56.4ms
# Speed: 2.5ms preprocess, 56.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, scissors 0.02, paper 0.02, 6.6ms
# Speed: 4.5ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.95, paper 0.03, scissors 0.02, 4.8ms
# Speed: 1.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 2 persons, 66.3ms
# Speed: 1.8ms preprocess, 66.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, paper 0.03, scissors 0.00, 5.3ms
# Speed: 3.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.03, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 58.4ms
# Speed: 12.2ms preprocess, 58.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, scissors 0.10, paper 0.03, 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.4ms
# Speed: 2.6ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.86, scissors 0.12, paper 0.03, 4.8ms
# Speed: 2.6ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 65.6ms
# Speed: 2.1ms preprocess, 65.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.88, scissors 0.09, paper 0.02, 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.8ms
# Speed: 2.1ms preprocess, 51.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, scissors 0.04, paper 0.01, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, scissors 0.03, paper 0.01, 6.9ms
# Speed: 3.0ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 50.7ms
# Speed: 2.6ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 7.3ms
# Speed: 3.2ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 56.7ms
# Speed: 2.2ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.95, scissors 0.03, paper 0.02, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.94, scissors 0.04, paper 0.02, 5.6ms
# Speed: 3.4ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.96, scissors 0.02, paper 0.02, 6.4ms
# Speed: 2.8ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 66.5ms
# Speed: 2.1ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.97, scissors 0.02, paper 0.01, 4.6ms
# Speed: 2.7ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 70.9ms
# Speed: 2.0ms preprocess, 70.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, paper 0.00, scissors 0.00, 7.6ms
# Speed: 4.1ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 50.5ms
# Speed: 2.5ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 53.9ms
# Speed: 1.9ms preprocess, 53.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 6.7ms
# Speed: 3.7ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.00, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 6.7ms
# Speed: 3.3ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 56.9ms
# Speed: 2.2ms preprocess, 56.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 60.6ms
# Speed: 3.3ms preprocess, 60.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 48.2ms
# Speed: 1.9ms preprocess, 48.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 15.9ms
# Speed: 3.6ms preprocess, 15.9ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 55.1ms
# Speed: 2.1ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 57.1ms
# Speed: 2.4ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.0ms
# Speed: 4.3ms preprocess, 7.0ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 59.4ms
# Speed: 2.4ms preprocess, 59.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 6.4ms
# Speed: 3.4ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 50.8ms
# Speed: 3.1ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 8.5ms
# Speed: 3.8ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.2ms
# Speed: 3.2ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 6.4ms
# Speed: 3.2ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 1.8ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.02, paper 0.01, 6.2ms
# Speed: 3.3ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 6.6ms
# Speed: 4.6ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.1ms
# Speed: 2.3ms preprocess, 54.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 51.9ms
# Speed: 2.2ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 7.4ms
# Speed: 3.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 53.8ms
# Speed: 1.9ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.98, scissors 0.01, paper 0.01, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.4ms
# Speed: 9.5ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 70.4ms
# Speed: 3.1ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.6ms
# Speed: 3.0ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 52.1ms
# Speed: 1.8ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 7.0ms
# Speed: 3.8ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.00, 5.9ms
# Speed: 3.6ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 59.3ms
# Speed: 2.2ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.3ms
# Speed: 3.8ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x224 rock 0.99, scissors 0.01, paper 0.01, 6.1ms
# Speed: 3.8ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 384x640 1 person, 54.6ms
# Speed: 2.2ms preprocess, 54.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
